# %% [markdown]
# # Week 12 - Milestone Two week

# %% [markdown]
# # 1. Lesson: no lesson this week.  Milestone Two is due!

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# Suppose you plot the number visitors to a museum over the seven days of a week; then again the following week.  Can you suggest the advantages and disadvantages of the following two ways of presenting the data?

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
time_series_0 = np.array([100, 110, 130, 120, 100, 90, 80])
time_series_1 = np.array([70, 90, 100, 100, 120, 110, 90])
fig, axs = plt.subplots(1, 2)
axs[0].plot(time_series_0)
axs[1].plot(time_series_1)
plt.subplots_adjust(wspace = 0)
plt.xlabel("Day of the week")
plt.ylabel("Number of visitors")
# Out:
# Text(0, 0.5, 'Number of visitors')

# %%
plt.plot(time_series_0)
plt.plot(time_series_1)
plt.xlabel("Day of the week")
plt.ylabel("Number of visitors")
# Out:
# Text(0, 0.5, 'Number of visitors')

# %% [markdown]
# ### Answer to Question

# %% [markdown]
# Using two side-by-side plots makes each week’s daily pattern very clear. It lets you see the rise and fall of visitors without any clutter. The downside is you can’t easily compare one week to the next on the same day because they’re on separate axes. Putting both lines on a single chart makes direct comparison simple. You can instantly see which week had more visitors on each day. The trade-off is that overlapping lines can cross or hide each other and make the chart feel crowded. Choose the split view when you want clean, individual patterns and pick the overlay when you need quick, day-by-day comparisons.

# %% [markdown]
# # 3. Working on your datasets
#
# This week, you can work on Milestone Two rather than having a particular exercise about working on your datasets

# %% [markdown]
# # 4. Storytelling With Data plot
#
# Reproduce any graph of your choice in p. 187-205 of the Storytelling With Data book as best you can. (Chapter Eight). You do not have to get the exact data values right, just the overall look and feel.

# %%
import numpy as np
import matplotlib.pyplot as plt


products = ['Product A', 'Product B', 'Product C', 'Product D', 'Product E']
years    = [2008, 2009, 2010, 2011, 2012, 2013, 2014]

price_data = [
    [390, 350,   np.nan,   np.nan,   np.nan],  # 2008
    [420, 400,   np.nan,   np.nan,   np.nan],  # 2009
    [430, 405,    100,     np.nan,   np.nan],  # 2010
    [390, 370,    180,     np.nan,   np.nan],  # 2011
    [300, 290,    200,      255,     np.nan],  # 2012
    [270, 260,    230,      220,     100 ],    # 2013
    [255, 245,    210,      210,     180 ],    # 2014
]

x = np.arange(len(products))
bar_width = 0.12

fig, ax = plt.subplots(figsize=(10, 6))

# plot one bar per year, offset from the center of each product
for i, year in enumerate(years):
    offsets = x + (i - len(years)/2) * bar_width + bar_width/2
    ax.bar(offsets, price_data[i], bar_width, label=str(year))


ax.set_xticks(x)
ax.set_xticklabels(products)
ax.set_ylim(0, 500)
ax.set_title('Average Retail Product Price Per Year')
ax.set_ylabel('Price ($)')
ax.legend(title='Year', bbox_to_anchor=(1.02, 1), loc='upper left')

plt.tight_layout()
plt.show()
